# %%
import numpy as np
import pandas as pd
import math
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import axes
import pickle
from datetime import datetime
from scipy import log,exp,sqrt,stats
print('Packages')

# %%
# Importing pickle file
data1 = np.load('/Users/louisribieras/Desktop/Invictus/Data/latest_coin_data.pkl')
data2 = np.load('/Users/louisribieras/Desktop/Invictus/Data/additional_data.pkl')

# Removing July dates from data1
data1 = data1.drop(data1.columns[0:4], axis = 1)

# Combining the two dataframes
data = pd.concat([data2, data1], axis = 1, join = 'outer', sort = True)

# Filling Nan values with 0
# data = data.replace(to_replace = np.nan, value = 0)
# dict1 = {'market_cap': 0,'volume': 0}
# data3 = data.fillna(value = dict1, inplace = True)
# data.isnull() = dict1

print('Loading of Data')
print('shape of data: ', data.shape)
# Out:
# Loading of Data
# shape of data:  (2549, 947)

# %%
data
# Out:
#                                                           Aug 04, 2018  \
# 007coin                                                            NaN
# 0chain               {'open_price': 0.248842, 'high_price': 0.28436...
# 0x                   {'open_price': 0.964003, 'high_price': 0.99142...
# 0xbtc                {'open_price': 0.521739, 'high_price': 0.66708...
# 0xcert               {'open_price': 0.021878, 'high_price': 0.02206...
# 10mtoken                                                           NaN
# 1337coin             {'open_price': 0.000104, 'high_price': 0.00012...
# 1coin                                                              NaN
# 1credit                                                            NaN
# 1world               {'open_price': 0.151054, 'high_price': 0.15336...
# 23-skidoo                                                          NaN
# 2bacco                                                             NaN
# 2give                {'open_price': 0.003905, 'high_price': 0.00412...
# 300-token                                                          NaN
# 404-coin                                                           NaN
# 42-coin              {'open_price': 20025.8, 'high_price': 20192.2,...
# 808coin              {'open_price': 4e-06, 'high_price': 1.4e-05, '...
# 8bit                 {'open_price': 0.091631, 'high_price': 0.09934...
# 9coin                                                              NaN
# ab-chain-rtb         {'open_price': 0.046055, 'high_price': 0.04771...
# abjcoin                                                            NaN
# abncoin                                                            NaN
# ac3                  {'open_price': 0.120187, 'high_price': 0.12765...
# accelerator-network  {'open_price': 0.284402, 'high_price': 0.41070...
# acchain              {'open_price': 0.148451, 'high_price': 0.14968...
# ace                  {'open_price': 0.084456, 'high_price': 0.08717...
# aced                 {'open_price': 0.208011, 'high_price': 0.22283...
# aces                 {'open_price': 0.000223, 'high_price': 0.00022...
# achain               {'open_price': 0.049723, 'high_price': 0.05157...
# acoin                {'open_price': 0.075032, 'high_price': 0.07920...
# ...                                                                ...
# zebi                 {'open_price': 0.028555, 'high_price': 0.02905...
# zedcoin                                                            NaN
# zeepin               {'open_price': 0.044571, 'high_price': 0.04588...
# zeitcoin             {'open_price': 4.4e-05, 'high_price': 5.1e-05,...
# zelcash              {'open_price': 0.029625, 'high_price': 0.03009...
# zencash              {'open_price': 24.22, 'high_price': 24.43, 'lo...
# zengold              {'open_price': 0.011816, 'high_price': 0.01190...
# zennies              {'open_price': 0.000445, 'high_price': 0.00044...
# zephyr               {'open_price': 0.018364, 'high_price': 0.01876...
# zero                 {'open_price': 0.261367, 'high_price': 0.28127...
# zetacoin             {'open_price': 0.002526, 'high_price': 0.00314...
# zetamicron           {'open_price': 7.5e-05, 'high_price': 7.5e-05,...
# zeusshield           {'open_price': 0.008666, 'high_price': 0.00873...
# ziftrcoin                                                          NaN
# zilbercoin                                                         NaN
# zilla                {'open_price': 0.061105, 'high_price': 0.06253...
# zilliqa              {'open_price': 0.058671, 'high_price': 0.06048...
# zinc                 {'open_price': 0.120891, 'high_price': 0.13617...
# zip                  {'open_price': 0.003054, 'high_price': 0.00315...
# zippie               {'open_price': 0.01245, 'high_price': 0.0125, ...
# zmine                {'open_price': 0.057746, 'high_price': 0.05889...
# zoin                 {'open_price': 0.064364, 'high_price': 0.06924...
# zombiecoin                                                         NaN
# zonecoin                                                           NaN
# zoom                                                               NaN
# zozocoin             {'open_price': 0.105747, 'high_price': 0.15026...
# zper                 {'open_price': 0.010495, 'high_price': 0.01141...
# zrcoin               {'open_price': 1.51, 'high_price': 1.52, 'low_...
# zsecoin              {'open_price': 0.003563, 'high_price': 0.00359...
# zurcoin              {'open_price': 0.001113, 'high_price': 0.00112...
#
#                                                           Aug 03, 2018  \
# 007coin                                                            NaN
# 0chain               {'open_price': 0.248764, 'high_price': 0.26684...
# 0x                   {'open_price': 0.954967, 'high_price': 1.01, '...
# 0xbtc                {'open_price': 0.68485, 'high_price': 0.69192,...
# 0xcert               {'open_price': 0.021429, 'high_price': 0.02206...
# 10mtoken                                                           NaN
# 1337coin             {'open_price': 0.000117, 'high_price': 0.00012...
# 1coin                                                              NaN
# 1credit                                                            NaN
# 1world               {'open_price': 0.152626, 'high_price': 0.15305...
# 23-skidoo                                                          NaN
# 2bacco                                                             NaN
# 2give                {'open_price': 0.003856, 'high_price': 0.00397...
# 300-token            {'open_price': 482.66, 'high_price': 482.66, '...
# 404-coin                                                           NaN
# 42-coin              {'open_price': 21425.4, 'high_price': 21425.4,...
# 808coin              {'open_price': 4e-06, 'high_price': 4e-06, 'lo...
# 8bit                 {'open_price': 0.061991, 'high_price': 0.11256...
# 9coin                                                              NaN
# ab-chain-rtb         {'open_price': 0.054887, 'high_price': 0.05488...
# abjcoin                                                            NaN
# abncoin                                                            NaN
# ac3                  {'open_price': 0.123481, 'high_price': 0.12456...
# accelerator-network  {'open_price': 0.332436, 'high_price': 0.33243...
# acchain              {'open_price': 0.263577, 'high_price': 0.26357...
# ace                  {'open_price': 0.092402, 'high_price': 0.09327...
# aced                 {'open_price': 0.242969, 'high_price': 0.25617...
# aces                 {'open_price': 0.000226, 'high_price': 0.00022...
# achain               {'open_price': 0.050706, 'high_price': 0.05271...
# acoin                {'open_price': 0.082908, 'high_price': 0.08290...
# ...                                                                ...
# zebi                 {'open_price': 0.02356, 'high_price': 0.029067...
# zedcoin                                                            NaN
# zeepin               {'open_price': 0.044651, 'high_price': 0.04601...
# zeitcoin             {'open_price': 3.8e-05, 'high_price': 4.5e-05,...
# zelcash              {'open_price': 0.026678, 'high_price': 0.03322...
# zencash              {'open_price': 24.85, 'high_price': 24.87, 'lo...
# zengold              {'open_price': 0.019876, 'high_price': 0.01987...
# zennies              {'open_price': 0.000528, 'high_price': 0.00052...
# zephyr               {'open_price': 0.016825, 'high_price': 0.01957...
# zero                 {'open_price': 0.252265, 'high_price': 0.27399...
# zetacoin             {'open_price': 0.001734, 'high_price': 0.00272...
# zetamicron           {'open_price': 7.5e-05, 'high_price': 7.5e-05,...
# zeusshield           {'open_price': 0.007852, 'high_price': 0.00914...
# ziftrcoin                                                          NaN
# zilbercoin                                                         NaN
# zilla                {'open_price': 0.066206, 'high_price': 0.06620...
# zilliqa              {'open_price': 0.05996, 'high_price': 0.060535...
# zinc                 {'open_price': 0.114424, 'high_price': 0.12468...
# zip                  {'open_price': 0.003302, 'high_price': 0.00330...
# zippie               {'open_price': 0.012268, 'high_price': 0.01246...
# zmine                {'open_price': 0.05821, 'high_price': 0.058278...
# zoin                 {'open_price': 0.069726, 'high_price': 0.07080...
# zombiecoin                                                         NaN
# zonecoin                                                           NaN
# zoom                                                               NaN
# zozocoin             {'open_price': 0.148283, 'high_price': 0.17856...
# zper                 {'open_price': 0.011404, 'high_price': 0.01140...
# zrcoin               {'open_price': 1.55, 'high_price': 1.56, 'low_...
# zsecoin              {'open_price': 0.004525, 'high_price': 0.00452...
# zurcoin              {'open_price': 0.000905, 'high_price': 0.00113...
#
#                                                           Aug 02, 2018  \
# 007coin                                                            NaN
# 0chain               {'open_price': 0.291109, 'high_price': 0.29520...
# 0x                   {'open_price': 1.06, 'high_price': 1.07, 'low_...
# 0xbtc                {'open_price': 0.711833, 'high_price': 0.73561...
# 0xcert               {'open_price': 0.021922, 'high_price': 0.02210...
# 10mtoken                                                           NaN
# 1337coin             {'open_price': 0.000123, 'high_price': 0.00012...
# 1coin                                                              NaN
# 1credit                                                            NaN
# 1world               {'open_price': 0.16033, 'high_price': 0.161923...
# 23-skidoo                                                          NaN
# 2bacco                                                             NaN
# 2give                {'open_price': 0.00389, 'high_price': 0.00407,...
# 300-token            {'open_price': 487.18, 'high_price': 492.85, '...
# 404-coin                                                           NaN
# 42-coin              {'open_price': 21672.3, 'high_price': 22041.1,...
# 808coin              {'open_price': 5e-06, 'high_price': 5e-06, 'lo...
# 8bit                 {'open_price': 0.112806, 'high_price': 0.11487...
# 9coin                                                              NaN
# ab-chain-rtb         {'open_price': 0.055622, 'high_price': 0.05837...
# abjcoin                                                            NaN
# abncoin                                                            NaN
# ac3                  {'open_price': 0.139521, 'high_price': 0.14300...
# accelerator-network  {'open_price': 0.339817, 'high_price': 0.40679...
# acchain              {'open_price': 0.265018, 'high_price': 0.26513...
# ace                  {'open_price': 0.09736, 'high_price': 0.097655...
# aced                 {'open_price': 0.247443, 'high_price': 0.26765...
# aces                 {'open_price': 0.000152, 'high_price': 0.00023...
# achain               {'open_price': 0.054207, 'high_price': 0.05587...
# acoin                {'open_price': 0.083962, 'high_price': 0.08493...
# ...                                                                ...
# zebi                 {'open_price': 0.025351, 'high_price': 0.02621...
# zedcoin                                                            NaN
# zeepin               {'open_price': 0.04462, 'high_price': 0.050043...
# zeitcoin             {'open_price': 4.7e-05, 'high_price': 4.8e-05,...
# zelcash              {'open_price': 0.026492, 'high_price': 0.02678...
# zencash              {'open_price': 26.2, 'high_price': 26.46, 'low...
# zengold              {'open_price': 0.009342, 'high_price': 0.01998...
# zennies              {'open_price': 0.000533, 'high_price': 0.00053...
# zephyr               {'open_price': 0.017107, 'high_price': 0.01819...
# zero                 {'open_price': 0.265328, 'high_price': 0.26756...
# zetacoin             {'open_price': 0.002027, 'high_price': 0.00239...
# zetamicron           {'open_price': 7.6e-05, 'high_price': 0.000151...
# zeusshield           {'open_price': 0.008423, 'high_price': 0.00912...
# ziftrcoin                                                          NaN
# zilbercoin                                                         NaN
# zilla                {'open_price': 0.070218, 'high_price': 0.07233...
# zilliqa              {'open_price': 0.066337, 'high_price': 0.06681...
# zinc                 {'open_price': 0.123695, 'high_price': 0.12838...
# zip                  {'open_price': 0.003526, 'high_price': 0.00371...
# zippie               {'open_price': 0.012432, 'high_price': 0.01276...
# zmine                {'open_price': 0.058491, 'high_price': 0.06000...
# zoin                 {'open_price': 0.06872, 'high_price': 0.07747,...
# zombiecoin                                                         NaN
# zonecoin                                                           NaN
# zoom                                                               NaN
# zozocoin             {'open_price': 1.15, 'high_price': 1.32, 'low_...
# zper                 {'open_price': 0.011856, 'high_price': 0.01207...
# zrcoin               {'open_price': 1.58, 'high_price': 1.61, 'low_...
# zsecoin              {'open_price': 0.00472, 'high_price': 0.004774...
# zurcoin              {'open_price': 0.000837, 'high_price': 0.00090...
#
#                                                           Aug 01, 2018  \
# 007coin                                                            NaN
# 0chain               {'open_price': 0.320679, 'high_price': 0.32737...
# 0x                   {'open_price': 1.1, 'high_price': 1.1, 'low_pr...
# 0xbtc                {'open_price': 0.738336, 'high_price': 0.78302...
# 0xcert               {'open_price': 0.027298, 'high_price': 0.02739...
# 10mtoken                                                           NaN
# 1337coin             {'open_price': 0.000133, 'high_price': 0.00013...
# 1coin                                                              NaN
# 1credit                                                            NaN
# 1world               {'open_price': 0.161489, 'high_price': 0.16177...
# 23-skidoo                                                          NaN
# 2bacco                                                             NaN
# 2give                {'open_price': 0.004173, 'high_price': 0.00417...
# 300-token            {'open_price': 503.54, 'high_price': 503.78, '...
# 404-coin                                                           NaN
# 42-coin              {'open_price': 24014.5, 'high_price': 24026.1,...
# 808coin              {'open_price': 4e-06, 'high_price': 5e-06, 'lo...
# 8bit                 {'open_price': 0.053306, 'high_price': 0.11566...
# 9coin                                                              NaN
# ab-chain-rtb         {'open_price': 0.063145, 'high_price': 0.06334...
# abjcoin                                                            NaN
# abncoin                                                            NaN
# ac3                  {'open_price': 0.178421, 'high_price': 0.18037...
# accelerator-network  {'open_price': 0.451037, 'high_price': 0.45252...
# acchain              {'open_price': 0.162681, 'high_price': 0.16276...
# ace                  {'open_price': 0.104499, 'high_price': 0.10865...
# aced                 {'open_price': 0.266863, 'high_price': 0.28301...
# aces                 {'open_price': 0.000155, 'high_price': 0.00022...
# achain               {'open_price': 0.05907, 'high_price': 0.059279...
# acoin                {'open_price': 0.084617, 'high_price': 0.08494...
# ...                                                                ...
# zebi                 {'open_price': 0.025682, 'high_price': 0.02599...
# zedcoin                                                            NaN
# zeepin               {'open_price': 0.044003, 'high_price': 0.05486...
# zeitcoin             {'open_price': 4.8e-05, 'high_price': 4.9e-05,...
# zelcash                                                            NaN
# zencash              {'open_price': 27.17, 'high_price': 27.29, 'lo...
# zengold              {'open_price': 0.010846, 'high_price': 0.01085...
# zennies              {'open_price': 0.000452, 'high_price': 0.00053...
# zephyr               {'open_price': 0.01568, 'high_price': 0.017793...
# zero                 {'open_price': 0.256649, 'high_price': 0.27273...
# zetacoin             {'open_price': 0.002385, 'high_price': 0.00277...
# zetamicron           {'open_price': 7.6e-05, 'high_price': 7.6e-05,...
# zeusshield           {'open_price': 0.008656, 'high_price': 0.00914...
# ziftrcoin                                                          NaN
# zilbercoin                                                         NaN
# zilla                {'open_price': 0.073456, 'high_price': 0.07408...
# zilliqa              {'open_price': 0.067276, 'high_price': 0.06827...
# zinc                 {'open_price': 0.093677, 'high_price': 0.12368...
# zip                  {'open_price': 0.00363, 'high_price': 0.003656...
# zippie               {'open_price': 0.013397, 'high_price': 0.01344...
# zmine                {'open_price': 0.058108, 'high_price': 0.05867...
# zoin                 {'open_price': 0.067575, 'high_price': 0.07660...
# zombiecoin                                                         NaN
# zonecoin                                                           NaN
# zoom                                                               NaN
# zozocoin             {'open_price': 0.099933, 'high_price': 2.6, 'l...
# zper                 {'open_price': 0.012089, 'high_price': 0.01302...
# zrcoin               {'open_price': 1.6, 'high_price': 1.62, 'low_p...
# zsecoin              {'open_price': 0.004028, 'high_price': 0.00472...
# zurcoin              {'open_price': 0.000852, 'high_price': 0.00085...
#
#                                                           Jul 31, 2018  \
# 007coin                                                            NaN
# 0chain               {'open_price': 0.34176, 'high_price': 0.355115...
# 0x                   {'open_price': 1.15, 'high_price': 1.15, 'low_...
# 0xbtc                {'open_price': 0.847388, 'high_price': 0.85760...
# 0xcert               {'open_price': 0.028487, 'high_price': 0.02974...
# 10mtoken                                                           NaN
# 1337coin             {'open_price': 0.00014, 'high_price': 0.000143...
# 1coin                                                              NaN
# 1credit                                                            NaN
# 1world               {'open_price': 0.170866, 'high_price': 0.17088...
# 23-skidoo                                                          NaN
# 2bacco                                                             NaN
# 2give                {'open_price': 0.004642, 'high_price': 0.00497...
# 300-token            {'open_price': 523.41, 'high_price': 523.65, '...
# 404-coin                                                           NaN
# 42-coin              {'open_price': 20984.2, 'high_price': 24101.9,...
# 808coin              {'open_price': 5e-06, 'high_price': 6e-06, 'lo...
# 8bit                 {'open_price': 0.068198, 'high_price': 0.06819...
# 9coin                                                              NaN
# ab-chain-rtb         {'open_price': 0.077331, 'high_price': 0.07734...
# abjcoin                                                            NaN
# abncoin                                                            NaN
# ac3                  {'open_price': 0.19759, 'high_price': 0.19759,...
# accelerator-network  {'open_price': 0.47755, 'high_price': 0.477639...
# acchain              {'open_price': 0.171022, 'high_price': 0.17102...
# ace                  {'open_price': 0.116345, 'high_price': 0.11634...
# aced                 {'open_price': 0.204295, 'high_price': 0.29927...
# aces                 {'open_price': 0.000164, 'high_price': 0.00016...
# achain               {'open_price': 0.069792, 'high_price': 0.06979...
# acoin                {'open_price': 0.083713, 'high_price': 0.08996...
# ...                                                                ...
# zebi                 {'open_price': 0.027741, 'high_price': 0.02774...
# zedcoin                                                            NaN
# zeepin               {'open_price': 0.048566, 'high_price': 0.04946...
# zeitcoin             {'open_price': 5.7e-05, 'high_price': 5.9e-05,...
# zelcash                                                            NaN
# zencash              {'open_price': 28.19, 'high_price': 30.04, 'lo...
# zengold              {'open_price': 0.010762, 'high_price': 0.01321...
# zennies              {'open_price': 0.000418, 'high_price': 0.00048...
# zephyr               {'open_price': 0.018335, 'high_price': 0.01836...
# zero                 {'open_price': 0.261331, 'high_price': 0.27787...
# zetacoin             {'open_price': 0.003537, 'high_price': 0.00353...
# zetamicron           {'open_price': 0.000164, 'high_price': 0.00016...
# zeusshield           {'open_price': 0.009515, 'high_price': 0.00967...
# ziftrcoin                                                          NaN
# zilbercoin                                                         NaN
# zilla                {'open_price': 0.084788, 'high_price': 0.08481...
# zilliqa              {'open_price': 0.071724, 'high_price': 0.07195...
# zinc                 {'open_price': 0.106111, 'high_price': 0.10696...
# zip                  {'open_price': 0.004229, 'high_price': 0.00430...
# zippie               {'open_price': 0.014176, 'high_price': 0.01421...
# zmine                                                              NaN
# zoin                 {'open_price': 0.069371, 'high_price': 0.07141...
# zombiecoin                                                         NaN
# zonecoin                                                           NaN
# zoom                                                               NaN
# zozocoin             {'open_price': 0.35344, 'high_price': 0.35344,...
# zper                 {'open_price': 0.014681, 'high_price': 0.01535...
# zrcoin               {'open_price': 1.74, 'high_price': 1.74, 'low_...
# zsecoin              {'open_price': 0.003263, 'high_price': 0.00409...
# zurcoin              {'open_price': 0.000899, 'high_price': 0.00089...
#
#                                                           Jul 30, 2018  \
# 007coin                                                            NaN
# 0chain               {'open_price': 0.372186, 'high_price': 0.37289...
# 0x                   {'open_price': 1.21, 'high_price': 1.21, 'low_...
# 0xbtc                {'open_price': 0.839748, 'high_price': 0.87460...
# 0xcert               {'open_price': 0.029185, 'high_price': 0.03008...
# 10mtoken                                                           NaN
# 1337coin             {'open_price': 0.000142, 'high_price': 0.00015...
# 1coin                                                              NaN
# 1credit                                                            NaN
# 1world               {'open_price': 0.175606, 'high_price': 0.17585...
# 23-skidoo                                                          NaN
# 2bacco                                                             NaN
# 2give                {'open_price': 0.004448, 'high_price': 0.00494...
# 300-token            {'open_price': 538.01, 'high_price': 539.19, '...
# 404-coin                                                           NaN
# 42-coin              {'open_price': 22529.7, 'high_price': 28941.4,...
# 808coin              {'open_price': 5e-06, 'high_price': 6e-06, 'lo...
# 8bit                 {'open_price': 0.077508, 'high_price': 0.07767...
# 9coin                                                              NaN
# ab-chain-rtb         {'open_price': 0.05925, 'high_price': 0.082377...
# abjcoin                                                            NaN
# abncoin                                                            NaN
# ac3                  {'open_price': 0.209296, 'high_price': 0.20929...
# accelerator-network  {'open_price': 0.604431, 'high_price': 0.60443...
# acchain                                                            NaN
# ace                  {'open_price': 0.116673, 'high_price': 0.11830...
# aced                 {'open_price': 0.197443, 'high_price': 0.20468...
# aces                 {'open_price': 0.000164, 'high_price': 0.00024...
# achain               {'open_price': 0.072717, 'high_price': 0.07291...
# acoin                {'open_price': 0.099595, 'high_price': 0.09981...
# ...                                                                ...
# zebi                 {'open_price': 0.029437, 'high_price': 0.02946...
# zedcoin                                                            NaN
# zeepin               {'open_price': 0.051323, 'high_price': 0.05132...
# zeitcoin             {'open_price': 5.8e-05, 'high_price': 6.6e-05,...
# zelcash                                                            NaN
# zencash              {'open_price': 29.75, 'high_price': 29.96, 'lo...
# zengold              {'open_price': 0.012994, 'high_price': 0.01301...
# zennies              {'open_price': 0.000408, 'high_price': 0.00041...
# zephyr               {'open_price': 0.020635, 'high_price': 0.02068...
# zero                 {'open_price': 0.250853, 'high_price': 0.26182...
# zetacoin             {'open_price': 0.003483, 'high_price': 0.00359...
# zetamicron           {'open_price': 0.000164, 'high_price': 0.00016...
# zeusshield           {'open_price': 0.008863, 'high_price': 0.01143...
# ziftrcoin                                                          NaN
# zilbercoin                                                         NaN
# zilla                {'open_price': 0.086268, 'high_price': 0.09169...
# zilliqa              {'open_price': 0.074767, 'high_price': 0.07476...
# zinc                 {'open_price': 0.109092, 'high_price': 0.11147...
# zip                  {'open_price': 0.004496, 'high_price': 0.00451...
# zippie               {'open_price': 0.013525, 'high_price': 0.0142,...
# zmine                                                              NaN
# zoin                 {'open_price': 0.081823, 'high_price': 0.08182...
# zombiecoin                                                         NaN
# zonecoin                                                           NaN
# zoom                                                               NaN
# zozocoin             {'open_price': 0.10644, 'high_price': 0.535965...
# zper                 {'open_price': 0.015145, 'high_price': 0.01630...
# zrcoin               {'open_price': 1.77, 'high_price': 1.77, 'low_...
# zsecoin              {'open_price': 0.00411, 'high_price': 0.004119...
# zurcoin              {'open_price': 0.000904, 'high_price': 0.00098...
#
#                                                           Jul 29, 2018  \
# 007coin                                                            NaN
# 0chain               {'open_price': 0.386164, 'high_price': 0.39037...
# 0x                   {'open_price': 1.24, 'high_price': 1.24, 'low_...
# 0xbtc                {'open_price': 0.84376, 'high_price': 0.906259...
# 0xcert               {'open_price': 0.029584, 'high_price': 0.03260...
# 10mtoken                                                           NaN
# 1337coin             {'open_price': 0.000159, 'high_price': 0.00016...
# 1coin                                                              NaN
# 1credit                                                            NaN
# 1world               {'open_price': 0.177016, 'high_price': 0.17805...
# 23-skidoo                                                          NaN
# 2bacco                                                             NaN
# 2give                {'open_price': 0.004504, 'high_price': 0.00459...
# 300-token            {'open_price': 533.24, 'high_price': 540.93, '...
# 404-coin                                                           NaN
# 42-coin              {'open_price': 24742.3, 'high_price': 24742.3,...
# 808coin              {'open_price': 5e-06, 'high_price': 6e-06, 'lo...
# 8bit                 {'open_price': 0.070354, 'high_price': 0.08367...
# 9coin                                                              NaN
# ab-chain-rtb         {'open_price': 0.066211, 'high_price': 0.07023...
# abjcoin                                                            NaN
# abncoin                                                            NaN
# ac3                  {'open_price': 0.206888, 'high_price': 0.21360...
# accelerator-network  {'open_price': 0.478892, 'high_price': 0.70047...
# acchain                                                            NaN
# ace                  {'open_price': 0.120225, 'high_price': 0.12117...
# aced                                                               NaN
# aces                 {'open_price': 0.000247, 'high_price': 0.00024...
# achain               {'open_price': 0.072875, 'high_price': 0.07355...
# acoin                {'open_price': 0.101422, 'high_price': 0.10209...
# ...                                                                ...
# zebi                 {'open_price': 0.030817, 'high_price': 0.03198...
# zedcoin                                                            NaN
# zeepin               {'open_price': 0.050685, 'high_price': 0.05158...
# zeitcoin             {'open_price': 6.1e-05, 'high_price': 6.1e-05,...
# zelcash                                                            NaN
# zencash              {'open_price': 30.43, 'high_price': 30.55, 'lo...
# zengold              {'open_price': 0.013147, 'high_price': 0.01323...
# zennies              {'open_price': 0.000493, 'high_price': 0.00049...
# zephyr               {'open_price': 0.019447, 'high_price': 0.02094...
# zero                 {'open_price': 0.302444, 'high_price': 0.30432...
# zetacoin             {'open_price': 0.003202, 'high_price': 0.00362...
# zetamicron           {'open_price': 0.000163, 'high_price': 0.00016...
# zeusshield           {'open_price': 0.00888, 'high_price': 0.008946...
# ziftrcoin                                                          NaN
# zilbercoin                                                         NaN
# zilla                {'open_price': 0.085172, 'high_price': 0.08735...
# zilliqa              {'open_price': 0.079948, 'high_price': 0.08025...
# zinc                 {'open_price': 0.118821, 'high_price': 0.11953...
# zip                  {'open_price': 0.004506, 'high_price': 0.00455...
# zippie               {'open_price': 0.013512, 'high_price': 0.01384...
# zmine                                                              NaN
# zoin                 {'open_price': 0.082977, 'high_price': 0.08582...
# zombiecoin                                                         NaN
# zonecoin                                                           NaN
# zoom                                                               NaN
# zozocoin             {'open_price': 1.96, 'high_price': 1.98, 'low_...
# zper                 {'open_price': 0.015711, 'high_price': 0.01585...
# zrcoin               {'open_price': 1.81, 'high_price': 1.83, 'low_...
# zsecoin              {'open_price': 0.004438, 'high_price': 0.00446...
# zurcoin              {'open_price': 0.000904, 'high_price': 0.00091...
#
#                                                           Jul 28, 2018  \
# 007coin                                                            NaN
# 0chain               {'open_price': 0.354788, 'high_price': 0.40270...
# 0x                   {'open_price': 1.15, 'high_price': 1.24, 'low_...
# 0xbtc                {'open_price': 0.797453, 'high_price': 0.96534...
# 0xcert               {'open_price': 0.029798, 'high_price': 0.03004...
# 10mtoken                                                           NaN
# 1337coin             {'open_price': 0.000156, 'high_price': 0.00016...
# 1coin                                                              NaN
# 1credit                                                            NaN
# 1world               {'open_price': 0.180134, 'high_price': 0.18517...
# 23-skidoo                                                          NaN
# 2bacco                                                             NaN
# 2give                {'open_price': 0.004568, 'high_price': 0.00468...
# 300-token                                                          NaN
# 404-coin                                                           NaN
# 42-coin              {'open_price': 23735.8, 'high_price': 38044.8,...
# 808coin              {'open_price': 5e-06, 'high_price': 5e-06, 'lo...
# 8bit                 {'open_price': 0.073706, 'high_price': 0.11418...
# 9coin                                                              NaN
# ab-chain-rtb         {'open_price': 0.080485, 'high_price': 0.08141...
# abjcoin                                                            NaN
# abncoin                                                            NaN
# ac3                  {'open_price': 0.225749, 'high_price': 0.2347,...
# accelerator-network  {'open_price': 0.509721, 'high_price': 0.57129...
# acchain                                                            NaN
# ace                  {'open_price': 0.119159, 'high_price': 0.12364...
# aced                                                               NaN
# aces                 {'open_price': 0.000244, 'high_price': 0.00024...
# achain               {'open_price': 0.07683, 'high_price': 0.077091...
# acoin                {'open_price': 0.099175, 'high_price': 0.10101...
# ...                                                                ...
# zebi                 {'open_price': 0.030963, 'high_price': 0.03105...
# zedcoin                                                            NaN
# zeepin               {'open_price': 0.050792, 'high_price': 0.05147...
# zeitcoin             {'open_price': 5.3e-05, 'high_price': 6e-05, '...
# zelcash                                                            NaN
# zencash              {'open_price': 31.23, 'high_price': 31.99, 'lo...
# zengold              {'open_price': 0.012774, 'high_price': 0.01685...
# zennies              {'open_price': 0.000327, 'high_price': 0.00049...
# zephyr               {'open_price': 0.020405, 'high_price': 0.02047...
# zero                 {'open_price': 0.282293, 'high_price': 0.30719...
# zetacoin             {'open_price': 0.00289, 'high_price': 0.003568...
# zetamicron           {'open_price': 8.2e-05, 'high_price': 8.2e-05,...
# zeusshield           {'open_price': 0.008917, 'high_price': 0.00939...
# ziftrcoin                                                          NaN
# zilbercoin                                                         NaN
# zilla                {'open_price': 0.087032, 'high_price': 0.08786...
# zilliqa              {'open_price': 0.075808, 'high_price': 0.08037...
# zinc                 {'open_price': 0.115166, 'high_price': 0.12579...
# zip                  {'open_price': 0.004535, 'high_price': 0.00462...
# zippie               {'open_price': 0.012632, 'high_price': 0.01375...
# zmine                                                              NaN
# zoin                 {'open_price': 0.087561, 'high_price': 0.08961...
# zombiecoin                                                         NaN
# zonecoin                                                           NaN
# zoom                                                               NaN
# zozocoin             {'open_price': 0.105579, 'high_price': 3.14, '...
# zper                 {'open_price': 0.016313, 'high_price': 0.01648...
# zrcoin               {'open_price': 1.86, 'high_price': 1.87, 'low_...
# zsecoin              {'open_price': 0.004576, 'high_price': 0.00460...
# zurcoin              {'open_price': 0.001144, 'high_price': 0.00131...
#
#                                                           Jul 27, 2018  \
# 007coin                                                            NaN
# 0chain               {'open_price': 0.350694, 'high_price': 0.36775...
# 0x                   {'open_price': 1.08, 'high_price': 1.18, 'low_...
# 0xbtc                {'open_price': 0.737706, 'high_price': 0.85371...
# 0xcert               {'open_price': 0.029783, 'high_price': 0.03046...
# 10mtoken                                                           NaN
# 1337coin             {'open_price': 0.000147, 'high_price': 0.00016...
# 1coin                                                              NaN
# 1credit                                                            NaN
# 1world               {'open_price': 0.179268, 'high_price': 0.18358...
# 23-skidoo                                                          NaN
# 2bacco                                                             NaN
# 2give                {'open_price': 0.004624, 'high_price': 0.00481...
# 300-token            {'open_price': 534.66, 'high_price': 555.93, '...
# 404-coin                                                           NaN
# 42-coin              {'open_price': 23651.4, 'high_price': 24737.3,...
# 808coin              {'open_price': 5e-06, 'high_price': 5e-06, 'lo...
# 8bit                 {'open_price': 0.074147, 'high_price': 0.07619...
# 9coin                                                              NaN
# ab-chain-rtb         {'open_price': 0.063888, 'high_price': 0.11375...
# abjcoin                                                            NaN
# abncoin                                                            NaN
# ac3                  {'open_price': 0.219035, 'high_price': 0.23006...
# accelerator-network  {'open_price': 0.684797, 'high_price': 0.68479...
# acchain              {'open_price': 0.317905, 'high_price': 0.31931...
# ace                  {'open_price': 0.117659, 'high_price': 0.13942...
# aced                                                               NaN
# aces                 {'open_price': 0.000238, 'high_price': 0.00024...
# achain               {'open_price': 0.076996, 'high_price': 0.08004...
# acoin                {'open_price': 0.094568, 'high_price': 0.10033...
# ...                                                                ...
# zebi                 {'open_price': 0.029794, 'high_price': 0.03117...
# zedcoin                                                            NaN
# zeepin               {'open_price': 0.045192, 'high_price': 0.05171...
# zeitcoin             {'open_price': 5.5e-05, 'high_price': 5.8e-05,...
# zelcash                                                            NaN
# zencash              {'open_price': 28.9, 'high_price': 32.66, 'low...
# zengold              {'open_price': 0.017228, 'high_price': 0.01893...
# zennies              {'open_price': 0.000315, 'high_price': 0.00033...
# zephyr               {'open_price': 0.017473, 'high_price': 0.02125...
# zero                 {'open_price': 0.25677, 'high_price': 0.287309...
# zetacoin             {'open_price': 0.003436, 'high_price': 0.00360...
# zetamicron           {'open_price': 7.9e-05, 'high_price': 0.000164...
# zeusshield           {'open_price': 0.008823, 'high_price': 0.00937...
# ziftrcoin                                                          NaN
# zilbercoin                                                         NaN
# zilla                {'open_price': 0.088619, 'high_price': 0.08970...
# zilliqa              {'open_price': 0.073314, 'high_price': 0.07681...
# zinc                 {'open_price': 0.119804, 'high_price': 0.12480...
# zip                  {'open_price': 0.004526, 'high_price': 0.00466...
# zippie               {'open_price': 0.012266, 'high_price': 0.01277...
# zmine                                                              NaN
# zoin                 {'open_price': 0.092595, 'high_price': 0.09328...
# zombiecoin                                                         NaN
# zonecoin                                                           NaN
# zoom                                                               NaN
# zozocoin             {'open_price': 0.200154, 'high_price': 0.47478...
# zper                 {'open_price': 0.014503, 'high_price': 0.01708...
# zrcoin               {'open_price': 1.84, 'high_price': 1.88, 'low_...
# zsecoin              {'open_price': 0.004448, 'high_price': 0.00462...
# zurcoin              {'open_price': 0.001033, 'high_price': 0.00115...
#
#                                                           Jul 26, 2018  \
# 007coin                                                            NaN
# 0chain               {'open_price': 0.374967, 'high_price': 0.40140...
# 0x                   {'open_price': 1.17, 'high_price': 1.19, 'low_...
# 0xbtc                {'open_price': 0.721581, 'high_price': 0.83924...
# 0xcert               {'open_price': 0.028699, 'high_price': 0.03082...
# 10mtoken                                                           NaN
# 1337coin             {'open_price': 0.000162, 'high_price': 0.00017...
# 1coin                                                              NaN
# 1credit                                                            NaN
# 1world               {'open_price': 0.174208, 'high_price': 0.21806...
# 23-skidoo                                                          NaN
# 2bacco                                                             NaN
# 2give                {'open_price': 0.004996, 'high_price': 0.00513...
# 300-token            {'open_price': 531.14, 'high_price': 563.89, '...
# 404-coin                                                           NaN
# 42-coin              {'open_price': 22781.0, 'high_price': 24256.3,...
# 808coin              {'open_price': 6e-06, 'high_price': 6e-06, 'lo...
# 8bit                 {'open_price': 0.092859, 'high_price': 0.10783...
# 9coin                                                              NaN
# ab-chain-rtb         {'open_price': 0.05501, 'high_price': 0.067759...
# abjcoin                                                            NaN
# abncoin                                                            NaN
# ac3                  {'open_price': 0.233999, 'high_price': 0.24056...
# accelerator-network  {'open_price': 0.634892, 'high_price': 0.71886...
# acchain              {'open_price': 0.205266, 'high_price': 0.33167...
# ace                  {'open_price': 0.115895, 'high_price': 0.12388...
# aced                                                               NaN
# aces                 {'open_price': 0.000245, 'high_price': 0.00024...
# achain               {'open_price': 0.081961, 'high_price': 0.08281...
# acoin                {'open_price': 0.099283, 'high_price': 0.10059...
# ...                                                                ...
# zebi                 {'open_price': 0.031907, 'high_price': 0.03223...
# zedcoin                                                            NaN
# zeepin               {'open_price': 0.046157, 'high_price': 0.05214...
# zeitcoin             {'open_price': 5.3e-05, 'high_price': 5.9e-05,...
# zelcash                                                            NaN
# zencash              {'open_price': 29.44, 'high_price': 31.13, 'lo...
# zengold              {'open_price': 0.017275, 'high_price': 0.01840...
# zennies              {'open_price': 0.00049, 'high_price': 0.000498...
# zephyr               {'open_price': 0.022062, 'high_price': 0.02302...
# zero                 {'open_price': 0.305011, 'high_price': 0.30737...
# zetacoin             {'open_price': 0.003392, 'high_price': 0.00369...
# zetamicron           {'open_price': 8.2e-05, 'high_price': 8.3e-05,...
# zeusshield           {'open_price': 0.008971, 'high_price': 0.00943...
# ziftrcoin                                                          NaN
# zilbercoin                                                         NaN
# zilla                {'open_price': 0.089878, 'high_price': 0.09521...
# zilliqa              {'open_price': 0.076988, 'high_price': 0.07914...
# zinc                 {'open_price': 0.129049, 'high_price': 0.14185...
# zip                  {'open_price': 0.004684, 'high_price': 0.00482...
# zippie               {'open_price': 0.013239, 'high_price': 0.01384...
# zmine                                                              NaN
# zoin                 {'open_price': 0.102974, 'high_price': 0.10331...
# zombiecoin                                                         NaN
# zonecoin                                                           NaN
# zoom                                                               NaN
# zozocoin             {'open_price': 0.081878, 'high_price': 0.67430...
# zper                 {'open_price': 0.015817, 'high_price': 0.01614...
# zrcoin               {'open_price': 1.86, 'high_price': 1.93, 'low_...
# zsecoin              {'open_price': 0.004658, 'high_price': 0.00472...
# zurcoin              {'open_price': 0.001062, 'high_price': 0.00107...
#
#                                            ...                          \
# 007coin                                    ...
# 0chain                                     ...
# 0x                                         ...
# 0xbtc                                      ...
# 0xcert                                     ...
# 10mtoken                                   ...
# 1337coin                                   ...
# 1coin                                      ...
# 1credit                                    ...
# 1world                                     ...
# 23-skidoo                                  ...
# 2bacco                                     ...
# 2give                                      ...
# 300-token                                  ...
# 404-coin                                   ...
# 42-coin                                    ...
# 808coin                                    ...
# 8bit                                       ...
# 9coin                                      ...
# ab-chain-rtb                               ...
# abjcoin                                    ...
# abncoin                                    ...
# ac3                                        ...
# accelerator-network                        ...
# acchain                                    ...
# ace                                        ...
# aced                                       ...
# ...
# zebi                                                               NaN
# zedcoin              {'open_price': 0.000241, 'high_price': 0.00024...
# zeepin                                                             NaN
# zeitcoin             {'open_price': 3e-06, 'high_price': 4e-06, 'lo...
# zelcash                                                            NaN
# zencash                                                            NaN
# zengold                                                            NaN
# zennies                                                            NaN
# zephyr                                                             NaN
# zero                                                               NaN
# zetacoin             {'open_price': 0.001755, 'high_price': 0.00208...
# zetamicron                                                         NaN
# zeusshield                                                         NaN
# ziftrcoin            {'open_price': 0.003334, 'high_price': 0.00407...
# zilbercoin                                                         NaN
# zilla                                                              NaN
# zilliqa                                                            NaN
# zinc                                                               NaN
# zip                                                                NaN
# zippie                                                             NaN
# zmine                                                              NaN
# zoin                                                               NaN
# zombiecoin                                                         NaN
# zonecoin                                                           NaN
# zoom                                                               NaN
# zozocoin                                                           NaN
# zper                                                               NaN
# zrcoin                                                             NaN
# zsecoin                                                            NaN
# zurcoin                                                            NaN
#
#                                                           Jan 03, 2016  \
# 007coin              {'open_price': 0.001474, 'high_price': 0.00147...
# 0chain                                                             NaN
# 0x                                                                 NaN
# 0xbtc                                                              NaN
# 0xcert                                                             NaN
# 10mtoken                                                           NaN
# 1337coin             {'open_price': 1.3e-05, 'high_price': 1.3e-05,...
# 1coin                                                              NaN
# 1credit                                                            NaN
# 1world                                                             NaN
# 23-skidoo            {'open_price': 1489.58, 'high_price': 1505.9, ...
# 2bacco                                                             NaN
# 2give                                                              NaN
# 300-token                                                          NaN
# 404-coin                                                           NaN
# 42-coin              {'open_price': 672.24, 'high_price': 737.36, '...
# 808coin                                                            NaN
# 8bit                 {'open_price': 0.015407, 'high_price': 0.01583...
# 9coin                                                              NaN
# ab-chain-rtb                                                       NaN
# abjcoin                                                            NaN
# abncoin                                                            NaN
# ac3                                                                NaN
# accelerator-network                                                NaN
# acchain                                                            NaN
# ace                                                                NaN
# aced                                                               NaN
# aces                                                               NaN
# achain                                                             NaN
# acoin                {'open_price': 0.002427, 'high_price': 0.00243...
# ...                                                                ...
# zebi                                                               NaN
# zedcoin              {'open_price': 0.000204, 'high_price': 0.00024...
# zeepin                                                             NaN
# zeitcoin             {'open_price': 3e-06, 'high_price': 4e-06, 'lo...
# zelcash                                                            NaN
# zencash                                                            NaN
# zengold                                                            NaN
# zennies                                                            NaN
# zephyr                                                             NaN
# zero                                                               NaN
# zetacoin             {'open_price': 0.001597, 'high_price': 0.00181...
# zetamicron                                                         NaN
# zeusshield                                                         NaN
# ziftrcoin            {'open_price': 0.004026, 'high_price': 0.00402...
# zilbercoin                                                         NaN
# zilla                                                              NaN
# zilliqa                                                            NaN
# zinc                                                               NaN
# zip                                                                NaN
# zippie                                                             NaN
# zmine                                                              NaN
# zoin                                                               NaN
# zombiecoin                                                         NaN
# zonecoin                                                           NaN
# zoom                                                               NaN
# zozocoin                                                           NaN
# zper                                                               NaN
# zrcoin                                                             NaN
# zsecoin                                                            NaN
# zurcoin                                                            NaN
#
#                                                           Jan 02, 2016  \
# 007coin              {'open_price': 0.001477, 'high_price': 0.00148...
# 0chain                                                             NaN
# 0x                                                                 NaN
# 0xbtc                                                              NaN
# 0xcert                                                             NaN
# 10mtoken                                                           NaN
# 1337coin             {'open_price': 1.3e-05, 'high_price': 1.7e-05,...
# 1coin                                                              NaN
# 1credit                                                            NaN
# 1world                                                             NaN
# 23-skidoo                                                          NaN
# 2bacco                                                             NaN
# 2give                                                              NaN
# 300-token                                                          NaN
# 404-coin                                                           NaN
# 42-coin              {'open_price': 745.41, 'high_price': 765.23, '...
# 808coin                                                            NaN
# 8bit                 {'open_price': 0.016303, 'high_price': 0.01635...
# 9coin                                                              NaN
# ab-chain-rtb                                                       NaN
# abjcoin                                                            NaN
# abncoin                                                            NaN
# ac3                                                                NaN
# accelerator-network                                                NaN
# acchain                                                            NaN
# ace                                                                NaN
# aced                                                               NaN
# aces                                                               NaN
# achain                                                             NaN
# acoin                {'open_price': 0.002345, 'high_price': 0.00243...
# ...                                                                ...
# zebi                                                               NaN
# zedcoin              {'open_price': 0.000208, 'high_price': 0.00024...
# zeepin                                                             NaN
# zeitcoin             {'open_price': 6e-06, 'high_price': 6e-06, 'lo...
# zelcash                                                            NaN
# zencash                                                            NaN
# zengold                                                            NaN
# zennies                                                            NaN
# zephyr                                                             NaN
# zero                                                               NaN
# zetacoin             {'open_price': 0.001739, 'high_price': 0.00188...
# zetamicron                                                         NaN
# zeusshield                                                         NaN
# ziftrcoin            {'open_price': 0.003832, 'high_price': 0.00424...
# zilbercoin                                                         NaN
# zilla                                                              NaN
# zilliqa                                                            NaN
# zinc                                                               NaN
# zip                                                                NaN
# zippie                                                             NaN
# zmine                                                              NaN
# zoin                                                               NaN
# zombiecoin                                                         NaN
# zonecoin                                                           NaN
# zoom                                                               NaN
# zozocoin                                                           NaN
# zper                                                               NaN
# zrcoin                                                             NaN
# zsecoin                                                            NaN
# zurcoin                                                            NaN
#
#                                                           Jan 01, 2016
# 007coin              {'open_price': 0.00149, 'high_price': 0.001501...
# 0chain                                                             NaN
# 0x                                                                 NaN
# 0xbtc                                                              NaN
# 0xcert                                                             NaN
# 10mtoken                                                           NaN
# 1337coin             {'open_price': 9e-06, 'high_price': 1.7e-05, '...
# 1coin                                                              NaN
# 1credit                                                            NaN
# 1world                                                             NaN
# 23-skidoo            {'open_price': 2153.6, 'high_price': 2181.23, ...
# 2bacco                                                             NaN
# 2give                                                              NaN
# 300-token                                                          NaN
# 404-coin                                                           NaN
# 42-coin              {'open_price': 737.94, 'high_price': 775.22, '...
# 808coin                                                            NaN
# 8bit                 {'open_price': 0.038034, 'high_price': 0.04207...
# 9coin                                                              NaN
# ab-chain-rtb                                                       NaN
# abjcoin                                                            NaN
# abncoin                                                            NaN
# ac3                                                                NaN
# accelerator-network                                                NaN
# acchain                                                            NaN
# ace                                                                NaN
# aced                                                               NaN
# aces                                                               NaN
# achain                                                             NaN
# acoin                {'open_price': 0.002583, 'high_price': 0.00266...
# ...                                                                ...
# zebi                                                               NaN
# zedcoin              {'open_price': 0.000208, 'high_price': 0.00020...
# zeepin                                                             NaN
# zeitcoin             {'open_price': 3e-06, 'high_price': 7e-06, 'lo...
# zelcash                                                            NaN
# zencash                                                            NaN
# zengold                                                            NaN
# zennies                                                            NaN
# zephyr                                                             NaN
# zero                                                               NaN
# zetacoin             {'open_price': 0.001714, 'high_price': 0.00186...
# zetamicron                                                         NaN
# zeusshield                                                         NaN
# ziftrcoin            {'open_price': 0.003102, 'high_price': 0.00383...
# zilbercoin                                                         NaN
# zilla                                                              NaN
# zilliqa                                                            NaN
# zinc                                                               NaN
# zip                                                                NaN
# zippie                                                             NaN
# zmine                                                              NaN
# zoin                                                               NaN
# zombiecoin                                                         NaN
# zonecoin                                                           NaN
# zoom                                                               NaN
# zozocoin                                                           NaN
# zper                                                               NaN
# zrcoin                                                             NaN
# zsecoin                                                            NaN
# zurcoin                                                            NaN
#
# [2549 rows x 947 columns]

# %%
print('Making Volumes dataframe (daily): volumes')

# Initialize a close_price list
volumes_list = list()
# Making a list of all close_prices
for date in data.index:
    for column in data.columns:
        if data[column][date] == dict:
            volumes_list.append(data[column][date]['volume'])
        else

# Splitting list into 133 lists (one per coin)
volumes_list = [volumes_list[i:i+947] for i  in range(0, len(volumes_list), 947)]   

volumes = pd.DataFrame(data = volumes_list, index = data.index, columns = data.columns)
# Reordering column index
volumes = volumes[volumes.columns[::-1]]

# Index to Datetime index
volumes.columns = pd.to_datetime(volumes.columns)

# Deleting first day
# del volumes['2016-01-03 00:00:00']

# original date index
data_index = volumes.columns

print('Shape of Volumes df: ', volumes.shape)
volumes.head(3)
# Out:
#   File "<ipython-input-39-ca6229dc7e7f>", line 10
#     else;
#         ^
# SyntaxError: invalid syntax
